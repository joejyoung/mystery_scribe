# %%
import sqlite3
import pandas as pd
import json

# %%
conn = sqlite3.connect("../database.db")
cursor = conn.cursor()

# %%
cursor.execute(
    "CREATE TABLE IF NOT EXISTS match(id INTEGER PRIMARY KEY, data TEXT)"
)

# %%
# match_data = pd.read_csv("../output/extracted_data.csv")

# %%
json_string = json.dumps(match_data)
cursor.execute(
    "INSERT INTO match (id, data) VALUES (?, json(?))", (json_string),
)
